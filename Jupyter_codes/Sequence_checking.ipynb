# %%
from Bio import SeqIO
Sequences =SeqIO.to_dict(SeqIO.parse("../Data/Sequences/A_gen.fasta","fasta"))

# %%
HLA_HLA00001 = Sequences["HLA:HLA00001"]
HLA_HLA15760 = Sequences["HLA:HLA15760"]
HLA_HLA16417 = Sequences["HLA:HLA16417"]
HLA_HLA16651 = Sequences["HLA:HLA16651"]
HLA_HLA17618 = Sequences["HLA:HLA17618"]
HLA_HLA18248 = Sequences["HLA:HLA18248"]

# %%
str(HLA_HLA00001.seq)==str(HLA_HLA15760.seq)
# Out:
# False

# %%
print(str(HLA_HLA00001.seq))
print("\n")
print(str(HLA_HLA15760.seq))
# Out:
# ...
#
#
# ...

# %%
str(HLA_HLA00001.seq)==str(HLA_HLA16417.seq)
# Out:
# True

# %%
str(HLA_HLA00001.seq)==str(HLA_HLA16651.seq)
# Out:
# True

# %%
str(HLA_HLA00001.seq)==str(HLA_HLA17618.seq)
# Out:
# True

# %%
str(HLA_HLA00001.seq)==str(HLA_HLA18248.seq)
# Out:
# True

# %%
HLA_HLA16415 = Sequences["HLA:HLA16415"]
HLA_HLA16652 = Sequences["HLA:HLA16652"]
HLA_HLA18976 = Sequences["HLA:HLA18976"]

# %%
str(HLA_HLA16415.seq)==str(HLA_HLA16652.seq)
# Out:
# False

# %%
str(HLA_HLA18976.seq)==str(HLA_HLA16652.seq)
# Out:
# False

# %%
str(HLA_HLA16415.seq)==str(HLA_HLA18976.seq)
# Out:
# False
