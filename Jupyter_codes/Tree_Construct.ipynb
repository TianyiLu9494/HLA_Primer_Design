# %% [markdown]
# #### DistanceTreeConstructor.
# <br>
# UPGMA (Unweighted Pair Group Method with Arithmetic Mean) and NJ (Neighbor Joining)

# %%
# Both algorithms construct trees based on a distance matrix
# so first we want to generate distance matrix
from Bio.Phylo.TreeConstruction import DistanceCalculator
from Bio import AlignIO
aln = AlignIO.read("../Data/Alignments/mafft_A.aln","clustal")
calculator = DistanceCalculator('identity')
dm = calculator.get_distance(aln)

# %%
#Neighbor Joining Tree
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
constructor = DistanceTreeConstructor(calculator, 'nj')
NJ_tree = constructor.build_tree(aln)

# %%
# UPGMA Tree
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
constructor = DistanceTreeConstructor(calculator, 'upgma')
U_tree = constructor.build_tree(aln)

# %% [markdown]
# While sometimes you might want to **use your own DistanceMatrix** directly instead of the raw alignment, we provide another direct way to use both algorithms.

# %%
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
constructor = DistanceTreeConstructor()
NJ_tree = constructor.nj(dm)

# %%
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
constructor = DistanceTreeConstructor()
U_tree = constructor.upgma(dm)

# %%
from Bio.Phylo.TreeConstruction import *
starting_tree = NJ_tree
scorer = ParsimonyScorer() # calculate the parsimony score of a target tree
searcher = NNITreeSearcher(scorer) # search the best tree that minimize the parsimony score
constructor = ParsimonyTreeConstructor(searcher, starting_tree)
pars_tree = constructor.build_tree(aln)

# %%
from Bio import Phylo

# %%
Phylo.draw_ascii(NJ_tree)
# Out:
#  , HLA:HLA20361
#  |
#  , HLA:HLA20756
#  |
#  , HLA:HLA19395
#  |
#  , HLA:HLA20879
#  |
#  | HLA:HLA00968
#  |
#  , HLA:HLA15859
#  |
#  , HLA:HLA13084
#  |
#  , HLA:HLA05227
#  |
#  , HLA:HLA15858
#  |
#  , HLA:HLA18894
#  |
#  , HLA:HLA18887
#  |
#  , HLA:HLA01032
#  |
#  , HLA:HLA15258
#  |
#  | HLA:HLA00036
#  |
#  | HLA:HLA15499
#  |
#  , HLA:HLA16094
#  |
#  , HLA:HLA19313
#  |
#  , HLA:HLA18889
#  |
#  , HLA:HLA18924
#  |
#  , HLA:HLA19481
#  |
#  , HLA:HLA15841
#  |
#  , HLA:HLA21863
#  |
#  | HLA:HLA21411
#  |
#  , HLA:HLA19409
#  |
#  , HLA:HLA15815
#  |
#  , HLA:HLA16430
#  |
#  , HLA:HLA13775
#  |
#  , HLA:HLA17586
#  |
#  , HLA:HLA00021
#  |
#  , HLA:HLA11198
#  |
#  , HLA:HLA19536
#  |
#  , HLA:HLA20643
#  |
#  | HLA:HLA15948
#  |
#  | HLA:HLA15853
#  |
#  , HLA:HLA18906
#  |
#  , HLA:HLA19476
#  |
#  , HLA:HLA01260
#  |
#  , HLA:HLA01575
#  |
#  | HLA:HLA00026
#  |
#  , HLA:HLA01035
#  |
#  , HLA:HLA01331
#  |
#  , HLA:HLA19312
#  |
#  , HLA:HLA02374
#  |
# ...

# %%
Phylo.write(NJ_tree,"/Users/tianyilu/HLA_Primer_Design/Data/Tree/clustalw_NJtree.xml", "phyloxml")
# Out:
# 1

# %%
Phylo.draw_ascii(pars_tree)
# Out:
#                                              ____ HLA_HLA13841
#   __________________________________________|
#  |                                          |    , HLA_HLA02537
#  |                                          |____|
#  |                                               | HLA_HLA00002
# _|
#  |                _______________________________ HLA_HLA04558
#  |               |
#  |               |                          ______________ HLA_HLA16097
#  |_______________|                 ________|
#                  |                |        |______________ HLA_HLA13763
#                  |                |
#                  |                |                     ____ HLA_HLA02891
#                  |________________|              ______|
#                                   |             |      |____ HLA_HLA13845
#                                   |             |
#                                   |             |           , HLA_HLA18724
# ...

# %%
help(Phylo.draw)
# Out:
# Help on function draw in module Bio.Phylo._utils:
#
# draw(tree, label_func=<class 'str'>, do_show=True, show_confidence=True, axes=None, branch_labels=None, label_colors=None, *args, **kwargs)
#     Plot the given tree using matplotlib (or pylab).
#
#     The graphic is a rooted tree, drawn with roughly the same algorithm as
#     draw_ascii.
#
#     Additional keyword arguments passed into this function are used as pyplot
#     options. The input format should be in the form of:
#     pyplot_option_name=(tuple), pyplot_option_name=(tuple, dict), or
#     pyplot_option_name=(dict).
#
#     Example using the pyplot options 'axhspan' and 'axvline':
#
#     >>> Phylo.draw(tree, axhspan=((0.25, 7.75), {'facecolor':'0.5'}),
#     ...     axvline={'x':'0', 'ymin':'0', 'ymax':'1'})
#
#     Visual aspects of the plot can also be modified using pyplot's own functions
#     and objects (via pylab or matplotlib). In particular, the pyplot.rcParams
# ...
